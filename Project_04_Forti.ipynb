# %% [markdown]
# # DSCI 303 – Project 04
# ### Lauren Forti

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Loading the Dataset; Preliminary Analysis
# Load the data into a DataFrame and explore the data set's structure.

# %%
# upload data into df
diamonds = pd.read_csv('diamonds.txt', sep='\t')

# show first 10 rows
display(diamonds.head(10))
# Out:
#     carat        cut color clarity  depth  table  price     x     y     z
# 1    0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2    0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3    0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4    0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5    0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 6    0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7    0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 8    0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 9    0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# Determine the size of the data set.

# %%
# print shape
print(diamonds.shape)
# Out:
# (53940, 10)

# %% [markdown]
# Inspect the DataFrame's distribution.

# %%
# get summary statistics
display(diamonds.describe())
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ## Part 2: Filtering and Sorting
# Display information for diamonds satisfying certain criteria. Start by viewing information about the 5 most expensive diamonds in the data set.

# %%
# get top 5 most expensive diamonds
display(diamonds.loc[:,['price', 'carat', 'cut', 'color', 'clarity']].sort_values('price', ascending = False).head())
# Out:
#        price  carat        cut color clarity
# 27750  18823   2.29    Premium     I     VS2
# 27749  18818   2.00  Very Good     G     SI1
# 27748  18806   1.51      Ideal     G      IF
# 27747  18804   2.07      Ideal     G     SI2
# 27746  18803   2.00  Very Good     H     SI1

# %% [markdown]
# View information about the 5 least expensive diamonds in the data set.

# %%
# get top 5 least expensive diamonds
display(diamonds.loc[:,['price', 'carat', 'cut', 'color', 'clarity']].sort_values('price').head())
# Out:
#    price  carat      cut color clarity
# 1    326   0.23    Ideal     E     SI2
# 2    326   0.21  Premium     E     SI1
# 3    327   0.23     Good     E     VS1
# 4    334   0.29  Premium     I     VS2
# 5    335   0.31     Good     J     SI2

# %% [markdown]
# View information about the 5 largest diamonds in the data set with an
# ideal cut.

# %%
# get top 5 largest diamonds w/ ideal cut
display(diamonds.loc[diamonds.loc[:, 'cut']=='Ideal',['price', 'carat', 'cut', 'color', 'clarity']].sort_values('carat', ascending=False).head())
# Out:
#        price  carat    cut color clarity
# 24329  12587   3.50  Ideal     H      I1
# 24298  12545   3.22  Ideal     I      I1
# 26468  16037   3.01  Ideal     J     SI2
# 26745  16538   3.01  Ideal     J      I1
# 24785  13156   2.75  Ideal     D      I1

# %% [markdown]
# View information about the 5 largest diamonds in the data set with an
# fair cut.

# %%
# get top 5 largest diamonds w/ fair cut
display(diamonds.loc[diamonds.loc[:, 'cut']=='Fair',['price', 'carat', 'cut', 'color', 'clarity']].sort_values('carat', ascending=False).head())
# Out:
#        price  carat   cut color clarity
# 27416  18018   5.01  Fair     J      I1
# 27631  18531   4.50  Fair     J      I1
# 27131  17329   4.13  Fair     H      I1
# 23645  11668   3.65  Fair     H      I1
# 26432  15964   3.40  Fair     D      I1

# %% [markdown]
# ## Part 3: Working with Categorical Variables
# Create lists to specify the order for each of the three categorical variables.

# %%
# list of categorical variable's levels from worst -> best
clarity_levels = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']
cut_levels = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_levels = ['J', 'I', 'H', 'G', 'F', 'E', 'D']

# %% [markdown]
# Use the lists to communicate to Pandas the correct order for the levels of the three categorical variables.

# %%
# convert to categorical variables
diamonds.clarity = pd.Categorical(diamonds.clarity, clarity_levels)
diamonds.cut = pd.Categorical(diamonds.cut, cut_levels)
diamonds.color = pd.Categorical(diamonds.color, color_levels)

# %% [markdown]
# Create lists of named colors to serve as palettes to be used for visualizations later.

# %%
# lists of colors
clarity_pal = ['firebrick', 'deeppink', 'coral', 'gold', 'limegreen', 'aqua', 'blue', 'darkviolet']
cut_pal = ['deeppink', 'gold', 'limegreen', 'aqua', 'darkviolet']
color_pal = ['firebrick', 'deeppink', 'coral', 'gold', 'limegreen', 'aqua', 'darkviolet']

# %% [markdown]
# ## Part 4: Displaying Counts for Categorical Variables
# Determine the number of diamonds with each level of each of the three categorical variables. Start by counting the number of diamonds for each level of **cut**.

# %%
display(diamonds.cut.value_counts().sort_index())
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Premium      13791
# Ideal        21551
# Name: cut, dtype: int64

# %% [markdown]
# Count the number of diamonds for each level of color.

# %%
display(diamonds.color.value_counts().sort_index())
# Out:
# J     2808
# I     5422
# H     8304
# G    11292
# F     9542
# E     9797
# D     6775
# Name: color, dtype: int64

# %% [markdown]
# Count the number of diamonds for each level of clarity.

# %%
display(diamonds.clarity.value_counts().sort_index())
# Out:
# I1        741
# SI2      9194
# SI1     13065
# VS2     12258
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# Name: clarity, dtype: int64

# %% [markdown]
# ## Part 5: Scatterplots of Price Against Carat
# Create scatter plots to explore the relationship between **price** and **carat**.

# %%
plt.figure(figsize=[8,6])

# make scatter plot of price vs carat
plt.scatter(x=diamonds.loc[:, 'carat'],
            y=diamonds.loc[:, 'price'],
            s=20,
            alpha=0.4,
            color='hotpink')

# add labels
plt.xlabel('Carat Size')
plt.ylabel('Price (in $)')
plt.title('Relationship between Diamond Price and Carat Size')

plt.show()

# %% [markdown]
# Reproduce the plot from above, but will now color the points according to their clarity.

# %%
plt.figure(figsize=[8,6])

# make scatter plot of price vs carat
for level in range(len(clarity_levels)):
    plt.scatter(x=diamonds.loc[diamonds.loc[:, 'clarity']==clarity_levels[level], 'carat'],
                y=diamonds.loc[diamonds.loc[:, 'clarity']==clarity_levels[level], 'price'],
                s=20,
                alpha=0.4,
                color=clarity_pal[level])

# add labels and legend
plt.legend(clarity_levels)
plt.xlabel('Carat Size')
plt.ylabel('Price (in $)')
plt.title('Relationship between Diamond Price and Carat Size')

plt.show()

# %% [markdown]
# Separate the points for each of the eight clarity levels into its own subplot.

# %%
plt.figure(figsize=[12,6])

# make scatter plot of price vs carat
for level in range(len(clarity_levels)):
    plt.subplot(2,4,level+1)
    plt.scatter(x=diamonds.loc[diamonds.loc[:, 'clarity']==clarity_levels[level], 'carat'],
                y=diamonds.loc[diamonds.loc[:, 'clarity']==clarity_levels[level], 'price'],
                s=20,
                alpha=0.4,
                color=clarity_pal[level])

    # add axes limits
    plt.xlim([0,4])
    plt.ylim([0,20000])
    
    # add labels
    plt.xlabel('Carat Size')
    plt.ylabel('Price (in $)')
    plt.title(clarity_levels[level])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 6: Applying Logarithmic Transformations
# Apply logarithmic transformations to **price** and **carat**, and explore the distribution of these transformed variables. Start by adding two new columns to the **diamonds** DataFrame to store the transformed variables.

# %%
# add cols for ln of carat and price
diamonds['ln_carat'] = np.log(diamonds.loc[:,'carat'])
diamonds['ln_price'] = np.log(diamonds.loc[:,'price'])

# %% [markdown]
# Explore the distribution of the diamond prices and the log of the diamond prices with histograms.

# %%
plt.figure(figsize=[12,4])

# make histogram of price
plt.subplot(1,2,1)
plt.hist(x=diamonds.loc[:, 'price'],
         edgecolor='k',
         color='dodgerblue',
         bins=20)
# add labels
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Histogram of Prices')

# make histogram of ln_price
plt.subplot(1,2,2)
plt.hist(x=diamonds.loc[:, 'ln_price'],
         edgecolor='k',
         color='dodgerblue',
         bins=20)
# add labels
plt.xlabel('Natural Log of Price')
plt.ylabel('Count')
plt.title('Histogram of Log-Prices')

plt.show()

# %% [markdown]
# Explore the distribution of the carat sizes and the log of the carat sizes with histograms.

# %%
plt.figure(figsize=[12,4])

# make histogram of carat
plt.subplot(1,2,1)
plt.hist(x=diamonds.loc[:, 'carat'],
         edgecolor='k',
         color='limegreen',
         bins=20)
# add labels
plt.xlabel('Carat Size')
plt.ylabel('Count')
plt.title('Histogram of Carat Sizes')

# make histogram of ln_carat
plt.subplot(1,2,2)
plt.hist(x=diamonds.loc[:, 'ln_carat'],
         edgecolor='k',
         color='limegreen',
         bins=20)
# add labels
plt.xlabel('Natural Log of Carat Size')
plt.ylabel('Count')
plt.title('Histogram of Log-Carat Sizes')

plt.show()

# %% [markdown]
# ## Part 7: Scatterplot of Transformed Variables
# Create a scatterplot of **ln_price** against **ln_carat**, with points colored according to their **clarity**.

# %%
plt.figure(figsize=[8,6])

# make scatter plot of ln_price vs ln_carat
for level in range(len(clarity_levels)):
    plt.scatter(x=diamonds.loc[diamonds.loc[:, 'clarity']==clarity_levels[level], 'ln_carat'],
                y=diamonds.loc[diamonds.loc[:, 'clarity']==clarity_levels[level], 'ln_price'],
                s=20,
                alpha=0.4,
                color=clarity_pal[level])
# add labels and legend
plt.legend(clarity_levels)
plt.xlabel('Natural Log of Carat Size')
plt.ylabel('Natural Log of Price')
plt.title('Relationship between Log-Price and Log-Carat Size')

plt.show()

# %% [markdown]
# ## Part 8: Grouping by Cut
# Create a grouped DataFrame displaying the mean price and carat size for each cut level.

# %%
# group selected cols by cut and calc mean
gb_cut = diamonds.loc[:,['cut', 'price', 'carat']].groupby('cut').mean()
display(gb_cut)
# Out:
#                  price     carat
# cut
# Fair       4358.757764  1.046137
# Good       3928.864452  0.849185
# Very Good  3981.759891  0.806381
# Premium    4584.257704  0.891955
# Ideal      3457.541970  0.702837

# %% [markdown]
# Graphically display the information from the DataFrame with a bar chart.

# %%
plt.figure(figsize = [12,4])

# plot bar chart for price
plt.subplot(1,2,1)
plt.bar(x=gb_cut.index.values,
        height=gb_cut.loc[:, 'price'],
        color=cut_pal,
        edgecolor='k')
# set title and labels
plt.title('Mean Price by Cut')
plt.xlabel('Cut')
plt.ylabel('Mean Price')

# plot bar chart for carat
plt.subplot(1,2,2)
plt.bar(x=gb_cut.index.values,
        height=gb_cut.loc[:, 'carat'],
        color=cut_pal,
        edgecolor='k')
# set title and labels
plt.title('Mean Carat Size by Cut')
plt.xlabel('Cut')
plt.ylabel('Mean Carat Size')

plt.show()

# %% [markdown]
# ## Part 9: Grouping by Color
# Create a grouped DataFrame displaying the mean price and carat size for each color level.

# %%
# group selected cols by cut and calc mean
gb_color = diamonds.loc[:,['color', 'price', 'carat']].groupby('color').mean()
display(gb_color)
# Out:
#              price     carat
# color
# J      5323.818020  1.162137
# I      5091.874954  1.026927
# H      4486.669196  0.911799
# G      3999.135671  0.771190
# F      3724.886397  0.736538
# E      3076.752475  0.657867
# D      3169.954096  0.657795

# %% [markdown]
# Graphically display the information from the DataFrame above with bar charts.

# %%
plt.figure(figsize = [12,4])

# plot bar chart for price
plt.subplot(1,2,1)
plt.bar(x=gb_color.index.values,
        height=gb_color.loc[:, 'price'],
        color=color_pal,
        edgecolor='k')
# set title and labels
plt.title('Mean Price by Color')
plt.xlabel('Color')
plt.ylabel('Mean Price')

# plot bar chart for carat
plt.subplot(1,2,2)
plt.bar(x=gb_color.index.values,
        height=gb_color.loc[:, 'carat'],
        color=color_pal,
        edgecolor='k')
# set title and labels
plt.title('Mean Carat Size by Color')
plt.xlabel('Color')
plt.ylabel('Mean Carat Size')

plt.show()

# %% [markdown]
# ## Part 10: Grouping by Clarity
# Create a grouped DataFrame displaying the mean price and carat size for each clarity level.

# %%
# group selected cols by cut and calc mean
gb_clarity = diamonds.loc[:,['clarity', 'price', 'carat']].groupby('clarity').mean()
display(gb_clarity)
# Out:
#                price     carat
# clarity
# I1       3924.168691  1.283846
# SI2      5063.028606  1.077648
# SI1      3996.001148  0.850482
# VS2      3924.989395  0.763935
# VS1      3839.455391  0.727158
# VVS2     3283.737071  0.596202
# VVS1     2523.114637  0.503321
# IF       2864.839106  0.505123

# %% [markdown]
# Graphically display the information from the DataFrame above with bar charts.

# %%
plt.figure(figsize = [12,4])

# plot bar chart for price
plt.subplot(1,2,1)
plt.bar(x=gb_clarity.index.values,
        height=gb_clarity.loc[:, 'price'],
        color=clarity_pal,
        edgecolor='k')
# set title and labels
plt.title('Mean Price by Clarity')
plt.xlabel('Clarity')
plt.ylabel('Mean Price')

# plot bar chart for carat
plt.subplot(1,2,2)
plt.bar(x=gb_clarity.index.values,
        height=gb_clarity.loc[:, 'carat'],
        color=clarity_pal,
        edgecolor='k')
# set title and labels
plt.title('Mean Carat Size by Clarity')
plt.xlabel('Clarity')
plt.ylabel('Mean Carat Size')

plt.show()
